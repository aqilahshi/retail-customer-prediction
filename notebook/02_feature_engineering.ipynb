# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../data/customer_future_features.csv")

df.head()
# Out:
#   customer_id  historical_revenue  total_orders  total_quantity  \
# 0    CUST0001             4122.92             3              16
# 1    CUST0002             1178.80             2               3
# 2    CUST0003               87.01             1               1
# 3    CUST0004               72.08             1               1
# 4    CUST0005              335.87             3               4
#
#    average_item_value  age  gender          city membership favorite_payment  \
# 0            412.2920   19  Female  Kuala Lumpur     Bronze   Online Banking
# 1            589.4000   43  Female     Shah Alam     Bronze      Credit Card
# 2             87.0100   19    Male  Kuala Lumpur     Bronze         E-Wallet
# 3             72.0800   27    Male   Johor Bahru     Bronze      Credit Card
# 4             83.9675   40    Male     Shah Alam     Bronze   Online Banking
#
#    ...        last_purchase customer_tenure_days days_since_last_purchase  \
# 0  ...  2026-04-08 12:50:57                    1                        2
# 1  ...  2025-11-30 18:24:28                  495                      130
# 2  ...  2025-12-29 22:26:55                  332                      101
# 3  ...  2025-08-24 07:24:47                  199                      229
# 4  ...  2026-03-27 19:29:43                  188                       13
#
#   purchase_frequency  average_items_per_order  historical_average_order_value  \
# 0             90.000                     5.33                         1374.31
# 1              0.121                     1.50                          589.40
# 2              0.090                     1.00                           87.01
# 3              0.151                     1.00                           72.08
# 4              0.479                     1.33                          111.96
#
#    future_revenue  future_orders  future_value_score  \
# 0            0.00              0        42393.672978
# 1          794.05              3         -696.964437
# 2         2311.44              3         -354.388581
# 3          682.75              3        -1289.624349
# 4          480.12              1          -93.757816
#
#    future_high_value_customer
# 0                           1
# 1                           0
# 2                           0
# 3                           0
# 4                           0
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   customer_id                     459 non-null    object
#  1   historical_revenue              459 non-null    float64
#  2   total_orders                    459 non-null    int64
#  3   total_quantity                  459 non-null    int64
#  4   average_item_value              459 non-null    float64
#  5   age                             459 non-null    int64
#  6   gender                          459 non-null    object
#  7   city                            459 non-null    object
#  8   membership                      459 non-null    object
#  9   favorite_payment                459 non-null    object
#  10  favorite_category               459 non-null    object
#  11  signup_date                     459 non-null    object
#  12  first_purchase                  459 non-null    object
#  13  last_purchase                   459 non-null    object
#  14  customer_tenure_days            459 non-null    int64
#  15  days_since_last_purchase        459 non-null    int64
#  16  purchase_frequency              459 non-null    float64
#  17  average_items_per_order         459 non-null    float64
#  18  historical_average_order_value  459 non-null    float64
#  19  future_revenue                  459 non-null    float64
#  20  future_orders                   459 non-null    int64
#  21  future_value_score              459 non-null    float64
#  22  future_high_value_customer      459 non-null    int64
# dtypes: float64(7), int64(7), object(9)
# memory usage: 82.6+ KB

# %%
columns_to_remove = [
    "customer_id",
    "signup_date",
    "first_purchase",
    "last_purchase",
    "future_revenue",
    "future_orders",
    "future_value_score"   # <-- Add this
]

df = df.drop(columns=columns_to_remove)

# %%
X = df.drop(
    columns="future_high_value_customer"
)

y = df["future_high_value_customer"]

# %%
X.select_dtypes(include="object").columns
# Out:
# Index(['gender', 'city', 'membership', 'favorite_payment',
#        'favorite_category'],
#       dtype='object')

# %%
X = pd.get_dummies(
    X,
    drop_first=True,
    dtype=int
)

# %%
print(X.shape)

X.head()
# Out:
# (459, 27)
#    historical_revenue  total_orders  total_quantity  average_item_value  age  \
# 0             4122.92             3              16            412.2920   19
# 1             1178.80             2               3            589.4000   43
# 2               87.01             1               1             87.0100   19
# 3               72.08             1               1             72.0800   27
# 4              335.87             3               4             83.9675   40
#
#    customer_tenure_days  days_since_last_purchase  purchase_frequency  \
# 0                     1                         2              90.000
# 1                   495                       130               0.121
# 2                   332                       101               0.090
# 3                   199                       229               0.151
# 4                   188                        13               0.479
#
#    average_items_per_order  historical_average_order_value  ...  \
# 0                     5.33                         1374.31  ...
# 1                     1.50                          589.40  ...
# 2                     1.00                           87.01  ...
# 3                     1.00                           72.08  ...
# 4                     1.33                          111.96  ...
#
#    membership_Platinum  membership_Silver  favorite_payment_Credit Card  \
# 0                    0                  0                             0
# 1                    0                  0                             1
# 2                    0                  0                             0
# 3                    0                  0                             1
# 4                    0                  0                             0
#
#    favorite_payment_Debit Card  favorite_payment_E-Wallet  \
# 0                            0                          0
# 1                            0                          0
# 2                            0                          1
# 3                            0                          0
# 4                            0                          0
#
#    favorite_payment_Online Banking  favorite_category_Electronics  \
# 0                                1                              1
# 1                                0                              1
# 2                                0                              0
# 3                                0                              0
# 4                                1                              0
#
#    favorite_category_Fashion  favorite_category_Home  favorite_category_Sports
# 0                          0                       0                         0
# 1                          0                       0                         0
# 2                          0                       1                         0
# 3                          1                       0                         0
# 4                          0                       0                         0
#
# [5 rows x 27 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
X_train.to_csv("../data/X_train.csv", index=False)
X_test.to_csv("../data/X_test.csv", index=False)
y_train.to_csv("../data/y_train.csv", index=False)
y_test.to_csv("../data/y_test.csv", index=False)

# %%
print("Training set:", X_train.shape)
print("Testing set:", X_test.shape)
print("\nTarget distribution:")
print(y.value_counts())
# Out:
# Training set: (367, 27)
# Testing set: (92, 27)
#
# Target distribution:
# future_high_value_customer
# 0    344
# 1    115
# Name: count, dtype: int64

# %%
y.value_counts()
# Out:
# future_high_value_customer
# 0    344
# 1    115
# Name: count, dtype: int64
